# %% [markdown]
# 2021년 10월 9일에 마지막으로 테스트하였습니다.
#
# 이 자료는 '위키독스 딥 러닝을 이용한 자연어 처리 입문, 네이버 영화 리뷰 튜토리얼입니다.'

# %% [markdown]
# 링크 : https://wikidocs.net/44249

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.3 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 65.2 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %% [markdown]
# # 1. 네이버 영화 리뷰 데이터에 대한 이해와 전처리

# %%
import pandas as pd
import urllib.request
import matplotlib.pyplot as plt
import re
from konlpy.tag import Okt
from tqdm import tqdm
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x7f690f75ebd0>)

# %%
train_data = pd.read_table('ratings_train.txt')
test_data = pd.read_table('ratings_test.txt')

# %%
print('훈련 샘플의 개수 :',len(train_data)) # 훈련용 리뷰 개수 출력
print('테스트 샘플의 개수 :',len(test_data)) # 테스트용 리뷰 개수 출력
# Out:
# 훈련 샘플의 개수 : 150000
# 테스트 샘플의 개수 : 50000

# %%
train_data[:5] # 상위 5개 출력
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
train_data['document'].nunique(), train_data['label'].nunique()
# Out:
# (146182, 2)

# %%
train_data.drop_duplicates(subset=['document'], inplace=True) # document 열에서 중복인 내용이 있다면 중복 제거

# %%
print('총 샘플의 수 :',len(train_data))
# Out:
# 총 샘플의 수 : 146183

# %%
train_data['label'].value_counts().plot(kind = 'bar')

# %%
print(train_data.groupby('label').size().reset_index(name = 'count'))
# Out:
#    label  count
# 0      0  73342
# 1      1  72841

# %%
print(train_data.isnull().values.any())
# Out:
# True

# %%
print(train_data.isnull().sum())
# Out:
# id          0
# document    1
# label       0
# dtype: int64

# %%
train_data.loc[train_data.document.isnull()]
# Out:
#             id document  label
# 25857  2172111      NaN      1

# %%
train_data = train_data.dropna(how = 'any') # Null 값이 존재하는 행 제거
print(train_data.isnull().values.any()) # Null 값이 존재하는지 확인
# Out:
# False

# %%
print(len(train_data))
# Out:
# 146182

# %%
train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# 한글과 공백을 제외하고 모두 제거
train_data[:5]
# Out:
#          id                                           document  label
# 0   9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1   3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1

# %%
train_data['document'] = train_data['document'].str.replace('^ +', "") # white space 데이터를 empty value로 변경
train_data['document'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())
# Out:
# id            0
# document    789
# label         0
# dtype: int64

# %%
train_data.loc[train_data.document.isnull()][:5]
# Out:
#            id document  label
# 404   4221289      NaN      0
# 412   9509970      NaN      1
# 470  10147571      NaN      1
# 584   7117896      NaN      0
# 593   6478189      NaN      0

# %%
train_data = train_data.dropna(how = 'any')

# %%
print(len(train_data))
# Out:
# 145393

# %%
test_data.drop_duplicates(subset = ['document'], inplace=True) # document 열에서 중복인 내용이 있다면 중복 제거
test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test_data['document'] = test_data['document'].str.replace('^ +', "") # 공백은 empty 값으로 변경
test_data['document'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test_data = test_data.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 48852

# %%
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 48852

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
okt = Okt()

# %%
X_train = []
for sentence in tqdm(train_data['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_train.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 145393/145393 [08:19<00:00, 290.88it/s]

# %%
X_test = []
for sentence in tqdm(test_data['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 48852/48852 [03:15<00:00, 249.74it/s]

# %%
print('전처리 후 테스트용 샘플의 개수 :',len(X_test))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 48852

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
print(tokenizer.word_index)
# Out:
# {'영화': 1, '보다': 2, '을': 3, '없다': 4, '이다': 5, '있다': 6, '좋다': 7, '너무': 8, '다': 9, '정말': 10, '되다': 11, '재밌다': 12, '적': 13, '만': 14, '같다': 15, '진짜': 16, '로': 17, '아니다': 18, '않다': 19, '점': 20, '에서': 21, '만들다': 22, '나오다': 23, '연기': 24, '것': 25, '평점': 26, '내': 27, '최고': 28, '그': 29, '나': 30, '안': 31, '인': 32, '스토리': 33, '생각': 34, '못': 35, '왜': 36, '드라마': 37, '게': 38, '감동': 39, '사람': 40, '보고': 41, '이렇다': 42, '말': 43, '고': 44, '아깝다': 45, '더': 46, '배우': 47, '때': 48, 'ㅋㅋ': 49, '아': 50, '감독': 51, '거': 52, '그냥': 53, '재미있다': 54, '요': 55, '재미': 56, '시간': 57, '내용': 58, '뭐': 59, '까지': 60, '중': 61, '주다': 62, '자다': 63, '하고': 64, '지루하다': 65, '재미없다': 66, '쓰레기': 67, '수': 68, '네': 69, '모르다': 70, '가다': 71, '들다': 72, '그렇다': 73, '싶다': 74, '지': 75, '작품': 76, '사랑': 77, '알다': 78, '하나': 79, '다시': 80, '마지막': 81, '볼': 82, '이건': 83, '정도': 84, '저': 85, '완전': 86, '오다': 87, 'ㅋ': 88, 'ㅠㅠ': 89, '많다': 90, '처음': 91, 'ㅋㅋㅋ': 92, '장면': 93, '액션': 94, '주인공': 95, '이렇게': 96, '안되다': 97, '걸': 98, '차다': 99, '나다': 100, '개': 101, '하': 102, '최악': 103, '돈': 104, '이야기': 105, '지금': 106, '넘다': 107, '느낌': 108, '임': 109, '연출': 110, 'ㅡㅡ': 111, '라': 112, '인데': 113, '듯': 114, '끝': 115, '명작': 116, '좋아하다': 117, '그리고': 118, '년': 119, '별로': 120, '역시': 121, '받다': 122, '기': 123, '많이': 124, '남다': 125, '별': 126, '이해': 127, '난': 128, '면': 129, '이런': 130, '이영화': 131, '분': 132, '괜찮다': 133, '라고': 134, '느끼다': 135, '또': 136, '버리다': 137, '이나': 138, '때문': 139, '성': 140, '여자': 141, '서': 142, '부터': 143, '먹다': 144, '일': 145, '아름답다': 146, '해주다': 147, '꼭': 148, '보기': 149, '엔': 150, '이고': 151, '두': 152, '무슨': 153, '여': 154, '에게': 155, '기억': 156, '결말': 157, '편': 158, '대': 159, 'ㅎㅎ': 160, '랑': 161, '야': 162, '짱': 163, '아쉽다': 164, '인생': 165, '마음': 166, '영': 167, '소재': 168, '뻔하다': 169, '끄다': 170, '애': 171, '전': 172, '보여주다': 173, '님': 174, '어떻다': 175, '없이': 176, '수준': 177, '어리다': 178, '현실': 179, '무섭다': 180, '맞다': 181, '한번': 182, '속': 183, '씨': 184, '가장': 185, '재다': 186, '급': 187, '본': 188, '웃기다': 189, '반전': 190, '매력': 191, '되어다': 192, '전개': 193, '제': 194, '라는': 195, '한국': 196, '남자': 197, '끝나다': 198, '가슴': 199, '뿐': 200, '낮다': 201, '말다': 202, '아이': 203, '죽다': 204, '슬프다': 205, '높다': 206, '유치하다': 207, '음악': 208, '알': 209, '니': 210, '다른': 211, '멋지다': 212, '원작': 213, '줄': 214, '늘다': 215, '인간': 216, '화': 217, '솔직하다': 218, '크다': 219, '냐': 220, '우리': 221, '추천': 222, '눈물': 223, '쓰다': 224, '살다': 225, '인지': 226, '모든': 227, '지만': 228, '내다': 229, '함': 230, '자체': 231, '번': 232, '야하다': 233, '허다': 234, '눈': 235, '찍다': 236, '하지만': 237, '인가': 238, '캐릭터': 239, '보이다': 240, '코미디': 241, '처럼': 242, 'ㅋㅋㅋㅋ': 243, '대한': 244, '움': 245, '모두': 246, '이상': 247, '뭔가': 248, '대박': 249, 'ㅠ': 250, '돼다': 251, '이네': 252, '전혀': 253, '이쁘다': 254, '연기력': 255, '건지다': 256, '여운': 257, '미치다': 258, '그래도': 259, '짜증나다': 260, '개봉': 261, '공감': 262, '일본': 263, '기대': 264, '기대하다': 265, '시리즈': 266, '근데': 267, '중간': 268, '지다': 269, '표현': 270, '영상': 271, '부분': 272, '아주': 273, '모습': 274, '에는': 275, '작': 276, '제목': 277, '계속': 278, '이랑': 279, '치다': 280, '귀엽다': 281, '이라': 282, '시키다': 283, 'ㅜㅜ': 284, '가족': 285, '내내': 286, '뭔': 287, '보지': 288, '믿다': 289, '진심': 290, '실망': 291, '몰입': 292, '밖에': 293, '후': 294, '짜다': 295, '기분': 296, '대단하다': 297, '연': 298, '작가': 299, '떨어지다': 300, '건': 301, '잔잔하다': 302, 'ㅎ': 303, '이제': 304, '위': 305, '웃다': 306, '요즘': 307, '공포': 308, '빠지다': 309, '스릴러': 310, '이라는': 311, '시': 312, '감': 313, '긴장감': 314, '개인': 315, '용': 316, '잼': 317, '조금': 318, '애니': 319, '대사': 320, '이유': 321, '알바': 322, '특히': 323, '제대로': 324, '삶': 325, '울다': 326, '극장': 327, '점도': 328, '노래': 329, '한테': 330, '딱': 331, '욕': 332, '굿': 333, '점수': 334, '잇다': 335, '시작': 336, '막장': 337, '이란': 338, '나름': 339, '오랜': 340, '이상하다': 341, '극': 342, '이지': 343, '예쁘다': 344, '깊다': 345, '에도': 346, '노잼': 347, '제일': 348, '차라리': 349, '놈': 350, '느껴지다': 351, '친구': 352, '해보다': 353, '영화로': 354, '당시': 355, '같이': 356, '어설프다': 357, '의미': 358, '절대': 359, '빼다': 360, '식': 361, '력': 362, '위해': 363, '류': 364, '세상': 365, '따뜻하다': 366, '찾다': 367, '몇': 368, '아직도': 369, '훌륭하다': 370, '이라고': 371, '년대': 372, '공포영화': 373, '명':  ...

# %%
print(tokenizer.word_counts.items())
# Out:
# odict_items([('아', 4138), ('더빙', 573), ('진짜', 8312), ('짜증나다', 1010), ('목소리', 374), ('흠', 251), ('포스터', 572), ('보고', 4658), ('초딩', 422), ('영화', 50367), ('줄', 1241), ('오버', 142), ('연기', 6326), ('조차', 242), ('가볍다', 361), ('않다', 7722), ('너', 670), ('무재', 69), ('밓었', 1), ('다그', 75), ('래서', 20), ('보다', 41072), ('추천', 1183), ('다', 10105), ('교도소', 16), ('이야기', 2171), ('구먼', 11), ('솔직하다', 1203), ('재미', 3879), ('없다', 15572), ('평점', 6266), ('조정', 40), ('사이', 222), ('몬페', 2), ('그', 5670), ('익살스럽다', 9), ('돋보이다', 288), ('스파이더맨', 64), ('에서', 6981), ('늙다', 198), ('보이다', 1074), ('커스틴', 4), ('던스트', 2), ('너무나도', 206), ('이쁘다', 1034), ('막', 333), ('걸음', 20), ('마', 236), ('떼다', 151), ('세', 599), ('부터', 1717), ('초등학교', 116), ('학년', 121), ('생인', 6), ('살다', 1173), ('ㅋㅋㅋ', 2448), ('별', 1928), ('반개', 205), ('아깝다', 4419), ('움', 1053), ('원작', 1253), ('긴장감', 832), ('을', 23208), ('제대로', 796), ('살리다', 534), ('욕', 779), ('나오다', 6397), ('이응경', 8), ('길용우', 4), ('연', 882), ('기', 1974), ('생활', 126), ('몇', 697), ('년', 1991), ('인지', 1173), ('정말', 9720), ('발', 300), ('로', 7834), ('해도', 440), ('그것', 444), ('보단', 508), ('낫다', 544), ('납치', 49), ('감금', 11), ('만', 8659), ('반복', 151), ('드라마', 5044), ('가족', 937), ('못', 5295), ('사람', 4836), ('모', 344), ('엿', 207), ('네', 3420), ('액션', 2394), ('있다', 12429), ('안되다', 2320), ('왜케', 131), ('낮다', 1315), ('꽤', 491), ('볼', 2738), ('데', 652), ('헐리우드', 143), ('식', 713), ('화려하다', 368), ('너무', 11124), ('길들이다', 20), ('인피니트', 27), ('짱', 1541), ('이다', 13196), ('볼때', 324), ('마다', 675), ('눈물나다', 174), ('죽다', 1295), ('년대', 689), ('향수', 66), ('극', 754), ('허진호', 6), ('감성', 420), ('절제', 67), ('멜로', 297), ('달인', 21), ('울면', 78), ('서', 1723), ('손', 277), ('고', 4501), ('횡단보도', 1), ('건너다', 8), ('때', 4279), ('뛰다', 171), ('치다', 948), ('올', 253), ('뻔', 312), ('이범수', 39), ('드럽다', 235), ('담백하다', 68), ('깔끔하다', 174), ('좋다', 12001), ('신', 547), ('문', 181), ('사', 332), ('로만', 139), ('자꾸', 263), ('잊어버리다', 15), ('것', 6286), ('취향', 274), ('존중', 36), ('다지', 18), ('내생', 106), ('극장', 794), ('중', 3728), ('가장', 1388), ('노잼', 746), ('노', 216), ('감동', 4844), ('임', 2076), ('스토리', 5332), ('어거지', 76), ('ㄱ', 115), ('냥', 178), ('매번', 65), ('긴장', 153), ('되다', 8852), ('재밋음', 82), ('ㅠㅠ', 2474), ('차다', 2305), ('웃기다', 1371), ('바스코', 15), ('이기', 168), ('면', 1873), ('락스', 13), ('코', 397), ('라고', 1787), ('끄다', 1491), ('바비', 24), ('아이돌', 148), ('이라고', 690), ('깔다', 211), ('안달', 22), ('난', 1875), ('처럼', 1065), ('굿바이', 21), ('레닌', 6), ('표절', 183), ('인', 5469), ('이해', 1895), ('왜', 5120), ('뒤', 531), ('갈수록', 512), ('없어지다', 135), ('이건', 2592), ('깨알', 68), ('캐스팅', 572), ('질퍽', 3), ('하', 2206), ('지', 3027), ('산뜻하다', 14), ('내', 5919), ('용구성', 6), ('자다', 3626), ('버무러진', 2), ('일드', 37), ('약탈', 4), ('위', 859), ('변명', 29), ('이르다', 392), ('저', 2578), ('놈', 740), ('착하다', 217), ('절대', 717), ('아니다', 7753), ('걸', 2320), ('요', 4029), ('나름', 760), ('심오하다', 100), ('뜻', 174), ('듯', 2039), ('그냥', 4062), ('학생', 133), ('선생', 64), ('놀다', 106), ('웃다', 856), ('건', 878), ('불가능하다', 48), ('재미없다', 3480), ('지루하다', 3508), ('같다', 8343), ('음식', 82), ('인데', 2060), ('바베트', 1), ('만찬', 9), ('하고', 3563), ('넘다', 2110), ('차이', 161), ('남바', 1), ('베트', 3), ('게', 4928), ('별로', 1990), ('안', 5495), ('핀란드', 8), ('풍경', 120), ('이라도', 400), ('구', 582), ('경', 132), ('할랫', 1), ('늘다', 1222), ('ㅡㅡ', 2067), ('평범하다', 301), ('수작', 643), ('이라', 947), ('는걸', 176), ('말씀드리다', 6), ('주제', 378), ('중반', 285), ('짤랐을꺼', 1), ('야', 1545), ('그래서', 473), ('납득', 55), ('수', 3433), ('그렇다', 3095), ('꼭', 1626), ('고추', 15), ('털다', 27), ('버리다', 1774), ('카밀라', 10), ('벨', 50), ('발연기', 441), ('재밋는뎅', 1), ('센스', 81), ('연출', 2075), ('력', 708), ('탁월하다', 66), ('점', 7547), ('엄포스', 3), ('위력', 12), ('다시', 2813), ('한번', 1405), ('깨닫다', 148), ('해주다', 1644), ('적남', 1), ('꽃', 92), ('검사', 55), ('님', 1464), ('완전', 2526), ('명품', 136), ('졸', 79), ('쓰레기', 3434), ('진부하다', 518), ('도안', 131), ('돼다', 1041), ('ㅋㅋ', 4276), ('아시', 42), ('간', 513), ('재밌다', 8802), ('이리', 469), ('라도', 406), ('기대하다', 997), ('죄인', 13), ('아직도', 695), ('인생', 1517), ('최고', 5785), ('패션', 38), ('대한', 1055), ('열정' ...

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 43752
# 등장 빈도가 2번 이하인 희귀 단어의 수: 24337
# 단어 집합에서 희귀 단어의 비율: 55.62488571950996
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.8715872104872904

# %%
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 19416

# %%
tokenizer = Tokenizer(vocab_size) # 빈도수 2 이하인 단어는 제거
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
y_train = np.array(train_data['label'])
y_test = np.array(test_data['label'])

# %%
print(len(X_train))
print(len(y_train))
# Out:
# 145393
# 145393

# %%
print(X_train[:3])
# Out:
# [[50, 454, 16, 260, 659], [933, 457, 41, 602, 1, 214, 1449, 24, 961, 675, 19], [386, 2444, 2315, 5671, 2, 222, 9]]

# %%
drop_train = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]
drop_test = [index for index, sentence in enumerate(X_test) if len(sentence) < 1]

# %%
print(drop_train)
# Out:
# [28, 414, 1149, 1347, 1572, 1711, 2321, 2345, 2432, 3440, 4289, 4612, 4809, 5021, 5722, 7141, 7790, 9660, 10596, 10973, 11669, 12722, 12766, 12896, 13788, 15427, 16782, 18597, 18626, 19286, 21297, 24351, 24583, 24871, 25031, 25860, 26313, 27110, 27497, 28474, 28600, 28938, 29596, 29618, 30187, 30623, 32218, 32462, 32874, 32885, 33701, 34017, 34216, 34919, 36295, 37099, 37481, 39648, 40010, 40364, 40665, 43207, 43312, 43410, 43838, 43922, 43984, 44094, 44629, 45388, 46359, 46788, 46909, 47456, 47865, 48205, 48827, 51094, 52043, 52778, 52980, 53565, 54640, 54875, 55519, 56274, 56971, 57036, 57277, 57391, 60421, 60439, 60718, 61783, 61949, 62106, 62592, 63085, 63487, 63632, 64232, 64332, 65184, 65481, 66049, 66665, 67697, 67928, 68049, 69478, 70138, 70510, 71315, 72129, 73255, 74008, 74186, 75521, 75921, 77418, 77739, 78027, 78051, 78416, 78887, 79170, 79754, 80550, 80662, 81848, 82858, 84521, 84990, 87275, 87381, 87490, 87497, 88069, 88706, 89022, 89292, 90566, 91144, 92800, 93043, 93533, 93688, 93846, 94305, 94979, 95111, 96054, 96549, 97197, 97553, 99679, 99897, 101281, 102635, 103264, 103378, 104239, 106932, 106945, 107060, 108231, 108344, 109975, 112592, 112873, 112917, 112985, 113714, 113797, 114137, 114152, 114706, 115900, 116290, 116411, 117039, 117851, 117981, 118051, 118137, 118288, 118376, 118583, 119369, 121148, 121472, 121934, 122086, 122127, 122151, 123631, 123764, 125367, 125689, 126069, 126423, 127718, 128030, 128617, 129124, 129461, 129543, 129728, 130558, 131619, 131779, 132581, 132745, 133151, 133159, 133373, 133778, 133912, 133998, 134921, 135563, 136054, 136633, 136694, 137063, 138242, 140695, 142085, 142537, 142606, 144870]

# %%
len(drop_train)
# Out:
# 231

# %%
X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
print(len(X_train))
print(len(y_train))
# Out:
# 145162
# 145162

# %%
print(len(X_test))
print(len(y_test))
# Out:
# 48852
# 48852

# %%
X_test = np.delete(X_test, drop_test, axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
y_test = np.delete(y_test, drop_test, axis=0)

# %%
print(len(X_test))
print(len(y_test))
# Out:
# 48745
# 48745

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 69
# 리뷰의 평균 길이 : 10.812485361182679

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 30
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 30 이하인 샘플의 비율: 94.31944999380003

# %%
# 전체 데이터의 길이는 30으로 맞춘다.
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %% [markdown]
# # 2. LSTM으로 네이버 영화 리뷰 감성 분류하기

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100))
model.add(LSTM(128))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 1815/1815 [==============================] - 16s 6ms/step - loss: 0.3897 - acc: 0.8229 - val_loss: 0.3491 - val_acc: 0.8452
#
# Epoch 00001: val_acc improved from -inf to 0.84521, saving model to best_model.h5
# Epoch 2/15
# 1815/1815 [==============================] - 10s 5ms/step - loss: 0.3263 - acc: 0.8592 - val_loss: 0.3328 - val_acc: 0.8560
#
# Epoch 00002: val_acc improved from 0.84521 to 0.85599, saving model to best_model.h5
# Epoch 3/15
# 1815/1815 [==============================] - 9s 5ms/step - loss: 0.3009 - acc: 0.8725 - val_loss: 0.3273 - val_acc: 0.8597
#
# Epoch 00003: val_acc improved from 0.85599 to 0.85971, saving model to best_model.h5
# Epoch 4/15
# 1815/1815 [==============================] - 9s 5ms/step - loss: 0.2816 - acc: 0.8822 - val_loss: 0.3253 - val_acc: 0.8600
#
# Epoch 00004: val_acc improved from 0.85971 to 0.86002, saving model to best_model.h5
# Epoch 5/15
# 1815/1815 [==============================] - 10s 5ms/step - loss: 0.2645 - acc: 0.8921 - val_loss: 0.3293 - val_acc: 0.8588
#
# Epoch 00005: val_acc did not improve from 0.86002
# Epoch 6/15
# 1815/1815 [==============================] - 9s 5ms/step - loss: 0.2482 - acc: 0.9006 - val_loss: 0.3364 - val_acc: 0.8593
#
# Epoch 00006: val_acc did not improve from 0.86002
# Epoch 7/15
# 1815/1815 [==============================] - 9s 5ms/step - loss: 0.2325 - acc: 0.9072 - val_loss: 0.3410 - val_acc: 0.8560
#
# Epoch 00007: val_acc did not improve from 0.86002
# Epoch 8/15
# 1815/1815 [==============================] - 9s 5ms/step - loss: 0.2162 - acc: 0.9150 - val_loss: 0.3609 - val_acc: 0.8534
#
# Epoch 00008: val_acc did not improve from 0.86002
# Epoch 00008: early stopping

# %%
loaded_model = load_model('best_model.h5')

# %%
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 1524/1524 [==============================] - 4s 2ms/step - loss: 0.3315 - acc: 0.8574
#
#  테스트 정확도: 0.8574

# %% [markdown]
# # 3. 리뷰 예측해보기

# %%
def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict('이 영화 개꿀잼 ㅋㅋㅋ')
# Out:
# 89.86% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('이 영화 핵노잼 ㅠㅠ')
# Out:
# 98.67% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('이딴게 영화냐 ㅉㅉ')
# Out:
# 99.77% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('감독 뭐하는 놈이냐?')
# Out:
# 98.63% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('와 개쩐다 정말 세계관 최강자들의 영화다')
# Out:
# 78.91% 확률로 긍정 리뷰입니다.
