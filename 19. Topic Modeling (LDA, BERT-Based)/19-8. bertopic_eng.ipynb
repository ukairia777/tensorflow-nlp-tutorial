# %% [markdown]
# 참고
# * https://www.maartengrootendorst.com/blog/bertopic/
# * https://hackernoon.com/nlp-tutorial-topic-modeling-in-python-with-bertopic-372w35l9

# %%
# !pip install bertopic[visualization]
# Out:
# Collecting bertopic[visualization]
#   Downloading bertopic-0.9.4-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 2.9 MB/s
# WARNING: bertopic 0.9.4 does not provide the extra 'visualization'
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from bertopic[visualization]) (1.3.5)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.7/dist-packages (from bertopic[visualization]) (4.62.3)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.7/dist-packages (from bertopic[visualization]) (5.5.0)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.2.tar.gz (86 kB)
#      |████████████████████████████████| 86 kB 5.3 MB/s
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 8.5 MB/s
# Collecting hdbscan>=0.8.27
#   Downloading hdbscan-0.8.28.tar.gz (5.2 MB)
#      |████████████████████████████████| 5.2 MB 54.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from bertopic[visualization]) (1.21.5)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.7/dist-packages (from bertopic[visualization]) (1.0.2)
# Requirement already satisfied: pyyaml<6.0 in /usr/local/lib/python3.7/dist-packages (from bertopic[visualization]) (3.13)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.27->bertopic[visualization]) (1.4.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.27->bertopic[visualization]) (1.1.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.27->bertopic[visualization]) (0.29.27)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (8.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.16.2-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 37.6 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.11.1+cu111)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 54.2 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.10.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (4.11.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4.2)
# Collecting pyyaml<6.0
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 65.2 MB/s
# Collecting tokenizers!=0.11.3,>=0.10.1
#   Downloading tokenizers-0.11.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 37.2 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 65.5 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.0.7)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.51.2)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.6.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 49.4 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (0.34.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (7.1.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (7.1.2)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2330746 sha256=c3feb508ec2e08584787e589192feca72660177969723d5c75028934a8b4e92e
#   Stored in directory: /root/.cache/pip/wheels/6e/7a/5e/259ccc841c085fc41b99ef4a71e896b62f5161f2bc8a14c97a
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=0b7fc1541139d74871bbe2a734707250ead473dd14ad84434235b9e0970d0786
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.2-py3-none-any.whl size=82708 sha256=a8f7137c12115d68b199e691dbe6d6db6251af5759898352d10e9960aca0611c
#   Stored in directory: /root/.cache/pip/wheels/84/1b/c6/aaf68a748122632967cef4dffef68224eb16798b6793257d82
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.6-py3-none-any.whl size=53943 sha256=2cc9b9eaac19b9926c86b2128ef90eff6b35d14d808c6f077ffe55320df9fc7c
#   Stored in directory: /root/.cache/pip/wheels/03/f1/56/f80d72741e400345b5a5b50ec3d929aca581bf45e0225d5c50
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, pynndescent, umap-learn, sentence-transformers, hdbscan, bertopic
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed bertopic-0.9.4 hdbscan-0.8.28 huggingface-hub-0.4.0 pynndescent-0.5.6 pyyaml-5.4.1 sacremoses-0.0.47 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.11.5 transformers-4.16.2 umap-learn-0.5.2

# %% [markdown]
# SBERT를 이용한 토픽 모델인 BERTopic은 별도 논문은 나오지 않은 모델이지만, 개발자는 BERTopic이 LDA를 대체할 수 있을만큼의 기술이라고 확신한다고 합니다. 여기서는 BERT 기반의 토픽 모델링 구현체인 BERTopic의 간단한 사용 방법에 대해서 다룹니다.

# %% [markdown]
# # 1. BERTopic

# %% [markdown]
# BERTopic은 BERT embeddings과 클래스 기반(class-based) TF-IDF를 활용하여 주제 설명에서 중요한 단어를 유지하면서도 쉽게 해석할 수 있는 조밀한 클러스터를 만드는 토픽 모델링 기술입니다. BERTopic 알고리즘은 크게 세 가지 과정을 거칩니다.

# %% [markdown]
# **1) 텍스트 데이터를 SBERT로 임베딩합니다.**
# 알고리즘은 SBERT를 사용하여 문서를 임베딩합니다. 이때, BERTopic은 기본적으로 아래의 BERT들을 사용합니다.
#
# * **"paraphrase-MiniLM-L6-v2"** : 영어 데이터로 학습된 SBERT
# * **"paraphrase-multilingual-MiniLM-L12-v2"** : 50개 이상의 언어로 학습된 다국어 SBERT

# %% [markdown]
# **2) 문서를 군집화합니다.**
# UMAP을 사용하여 임베딩의 차원을 줄이고 HDBSCAN 기술을 사용하여 차원 축소된 임베딩을 클러스터링하고 의미적으로 유사한 문서 클러스터를 생성합니다.

# %% [markdown]
# **3) 토픽 표현을 생성**
# 마지막 단계는 클래스 기반 TF-IDF로 토픽을 추출합니다.

# %% [markdown]
# # 2. 데이터 로드

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

# %%
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
# 상위 5개의 샘플 출력
docs[:5]
# Out:
# ["\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n",
#  'My brother is in the market for a high-performance video card that supports\nVESA local bus with 1-2MB RAM.  Does anyone have suggestions/ideas on:\n\n  - Diamond Stealth Pro Local Bus\n\n  - Orchid Farenheit 1280\n\n  - ATI Graphics Ultra Pro\n\n  - Any other high-performance VLB card\n\n\nPlease post or email.  Thank you!\n\n  - Matt\n',
#  '\n\n\n\n\tFinally you said what you dream about. Mediterranean???? That was new....\n\tThe area will be "greater" after some years, like your "holocaust" numbers......\n\n\n\n\n\t\t*****\n\tIs\'t July in USA now????? Here in Sweden it\'s April and still cold.\n\tOr have you changed your calendar???\n\n\n\t\t\t\t\t\t    ****************\n\t\t\t\t\t\t    ******************\n\t\t\t    ***************\n\n\n\tNOTHING OF THE MENTIONED IS TRUE, BUT LET SAY IT\'s TRUE.\n\t\n\tSHALL THE AZERI WOMEN AND CHILDREN GOING TO PAY THE PRICE WITH\n\t\t\t\t\t\t    **************\n\tBEING RAPED, KILLED AND TORTURED BY THE ARMENIANS??????????\n\t\n\tHAVE YOU HEARDED SOMETHING CALLED: "GENEVA CONVENTION"???????\n\tYOU FACIST!!!!!\n\n\n\n\tOhhh i forgot, this is how Armenians fight, nobody has forgot\n\tyou killings, rapings and torture against the Kurds and Turks once\n\tupon a time!\n      \n       \n\n\nOhhhh so swedish RedCross workers do lie they too? What ever you say\n"regional killer", if you don\'t like the person then shoot him that\'s your policy.....l\n\n\n\t\t\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n\tConfused?????\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n        Search Turkish planes? You don\'t know what you are talking about.\ti\n        Turkey\'s government has announced that it\'s giving weapons  <-----------i\n        to Azerbadjan since Armenia started to attack Azerbadjan\t\t\n        it self, not the Karabag province. So why search a plane for weapons\t\n        since it\'s content is announced to be weapons?   \n\n\tIf there is one that\'s confused then that\'s you! We have the right (and we do)\n\tto give weapons to the Azeris, since Armenians started the fight in Azerbadjan!\n \n\n\n\tShoot down with what? Armenian bread and butter? Or the arms and personel \n\tof the Russian army?\n\n\n',
#  "\nThink!\n\nIt's the SCSI card doing the DMA transfers NOT the disks...\n\nThe SCSI card can do DMA transfers containing data from any of the SCSI devices\nit is attached when it wants to.\n\nAn important feature of SCSI is the ability to detach a device. This frees the\nSCSI bus for other devices. This is typically used in a multi-tasking OS to\nstart transfers on several devices. While each device is seeking the data the\nbus is free for other commands and data transfers. When the devices are\nready to transfer the data they can aquire the bus and send the data.\n\nOn an IDE bus when you start a transfer the bus is busy until the disk has seeked\nthe data and transfered it. This is typically a 10-20ms second lock out for other\nprocesses wanting the bus irrespective of transfer time.\n",
#  '1)    I have an old Jasmine drive which I cannot use with my new system.\n My understanding is that I have to upsate the driver with a more modern\none in order to gain compatability with system 7.0.1.  does anyone know\nof an inexpensive program to do this?  ( I have seen formatters for <$20\nbuit have no idea if they will work)\n \n2)     I have another ancient device, this one a tape drive for which\nthe back utility freezes the system if I try to use it.  THe drive is a\njasmine direct tape (bought used for $150 w/ 6 tapes, techmar\nmechanism).  Essentially I have the same question as above, anyone know\nof an inexpensive beckup utility I can use with system 7.0.1']

# %%
print('총 문서의 수 :', len(docs))
# Out:
# 총 문서의 수 : 18846

# %% [markdown]
# # 3. 토픽 모델링

# %% [markdown]
# BERTopic의 fit_transform 메소드에 문자열들의 리스트를 입력으로 넣으면 토픽 모델링을 수행합니다.

# %%
model = BERTopic()
topics, probabilities = model.fit_transform(docs)

# %%
print('각 문서의 토픽 번호 리스트 :',len(topics))
print('첫번째 문서의 토픽 번호 :', topics[0])
# Out:
# 각 문서의 토픽 번호 리스트 : 18846
# 첫번째 문서의 토픽 번호 : 0

# %% [markdown]
# get_topic_info() 메소드를 사용하여 토픽의 개수, 토픽의 크기, 각 토픽에 할당된 단어들을 일부 볼 수 있습니다.

# %%
# 각 토픽의 크기와 각 토픽에 할당된 단어들
model.get_topic_info()
# Out:
#      Topic  Count                                   Name
# 0       -1   6514                        -1_to_the_of_is
# 1        0   1825                   0_game_team_games_he
# 2        1    572          1_key_clipper_chip_encryption
# 3        2    525                   2_ites_cheek_yep_huh
# 4        3    465             3_israel_israeli_jews_arab
# ..     ...    ...                                    ...
# 207    206     10          206_fat_weight_insulin_muscle
# 208    207     10         207_beeps_error_machine_chimes
# 209    208     10  208_colormap_colormaps_color_readonly
# 210    209     10           209_eisa_isa_bus_motherboard
# 211    210     10     210_memory_shared_server_xputimage
#
# [212 rows x 3 columns]

# %% [markdown]
# Count 열의 값을 모두 합하면 총 문서의 수입니다.

# %%
model.get_topic_info()['Count'].sum()
# Out:
# 18846

# %% [markdown]
# 위의 출력에서 Topic -1이 가장 큰 것으로 보입니다. -1은 토픽이 할당되지 않은 모든 이상치 문서(outliers)들을 나타냅니다. 현재 0번 토픽부터 210번 토픽까지 있는데, 임의로 5번 토픽에 대해서 단어들을 출력해봅시다.
#
# get_topic() 메소드의 입력으로 보고자하는 토픽의 번호를 넣어줍니다.

# %%
model.get_topic(5)
# Out:
# [('drive', 0.036501379524217024),
#  ('scsi', 0.027358077330910547),
#  ('drives', 0.0229861502896249),
#  ('ide', 0.019274207233754368),
#  ('disk', 0.01808211458113983),
#  ('controller', 0.016803056719952875),
#  ('hard', 0.013004806725656367),
#  ('scsi2', 0.012107882273732159),
#  ('bios', 0.009949766797753059),
#  ('scsi1', 0.009350150086818809)]

# %% [markdown]
# # 4. 토픽 시각화

# %% [markdown]
# BerTopic을 사용하면 LDAvis와 매우 유사한 방식으로 생성된 토픽을 시각화할 수 있습니다. 시각화를 통해 생성된 토픽에 대해 더 많은 통찰력을 얻을 수 있습니다. 우선 visualize_topics() 메소드로 시각화를 진행해봅시다.

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7b174e37-4c8b-4098-a261-85c889889eda" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b174e37-4c8b-4098-a261-85c889889eda")) {                    Plotly.newPlot(                        "7b174e37-4c8b-4098-a261-85c889889eda",                        [{"customdata":[[0,"game | team | games | he | players",1825],[1,"key | clipper | chip | encryption | keys",572],[2,"ites | cheek | yep | huh | ken",525],[3,"israel | israeli | jews | arab | jewish",465],[4,"monitor | card | video | drivers | vga",442],[5,"drive | scsi | drives | ide | disk",392],[6,"bike | ride | riding | my | lane",208],[7,"amp | audio | sound | stereo | condition",180],[8,"space | launch | station | nasa | shuttle",161],[9,"car | cars | mustang | ford | v8",159],[10,"bike | tires | tire | bikes | miles",157],[11,"drive | meg | ram | motherboard | monitor",153],[12,"ted | post | frank | you | posts",151],[13,"gun | guns | crime | firearms | homicide",142],[14,"printer | hp | deskjet | printers | ink",121],[15,"graphics | 3d | conference | nok | oprows",118],[16,"window | widget | application | event | expose",117],[17,"db | mov | windows | dos | memory",115],[18,"atheists | atheism | god | atheist | argument",109],[19,"moral | morality | objective | immoral | morals",109],[20,"health | tobacco | cesarean | smokeless | malaria",108],[21,"armenian | armenians | turkish | genocide | turkey",99],[22,"cancer | doctor | medical | patients | disease",96],[23,"venus | spacecraft | solar | mars | planets",94],[24,"men | sex | kinsey | homosexual | gay",90],[25,"dos | pom | cds | mpc | 2500",87],[26,"islam | quran | islamic | rushdie | muslims",87],[27,"modem | port | serial | irq | ports",85],[28,"ham | radio | interference | antenna | rf",84],[29,"pain | migraine | migraines | patients | sleep",84],[30,"russia | tax | administration | senior | president",81],[31,"serbs | muslims | stephanopoulos | mr | bosnia",81],[32,"games | joystick | sega | game | snes",80],[33,"koresh | batf | fbi | compound | children",75],[34,"simms | simm | dram | ram | meg",75],[35,"homosexuality | homosexual | paul | sex | homosexuals",74],[36,"mbytes | windows | dos | ms | mouse",71],[37,"format | gif | files | convert | file",69],[38,"windows | os2 | nt | apps | dos",69],[39,"modem | fax | modems | courier | v32bis",68],[40,"polygon | xxxx | edge | polygons | algorithm",65],[41,"fonts | font | truetype | tt | atm",63],[42,"candida | yeast | infection | infections | antibiotic",60],[43,"sky | advertising | billboard | billboards | light",58],[44,"batf | warrant | raid | they | assault",55],[45,"paradox | borland | windows | sql | engine",54],[46,"radar | detector | detectors | ka | traffic",53],[47,"mary | her | she | bernadette | sin",52],[48,"reno | fbi | president | waco | federal",51],[49,"militia | amendment | arms | bear | right",50],[50,"msg | food | chinese | foods | glutamate",49],[51,"ripem | key | des | rsa | privacy",49],[52,"science | methodology | scientific | theory | empirical",49],[53,"hell | eternal | god | jesus | heaven",49],[54,"paint | wax | plastic | scratches | finish",48],[55,"copy | protection | program | software | backup",47],[56,"mhz | bus | 486dx250 | speed | cpu",46],[57,"drugs | drug | cocaine | marijuana | lsd",45],[58,"mouse | driver | mice | ball | problem",45],[59,"server | xdm |  | login | error",44],[60,"miles | toyota | condition | amfm | interior",43],[61,"were | they | azerbaijan | armenians | her",43],[62,"kuwait | iraq | iran | gulf | arabia",42],[63,"hst | reboost | mission | shuttle | orbit",42],[64,"book | books | chemistry | scrolls | paperback",42],[65,"guide | price | shipping | manuals | disks",41],[66,"insurance | geico | car | accident | rates",41],[6 ...

# %% [markdown]
# # 5. 단어 시각화

# %% [markdown]
# Visualization_barchart() 메소드는 c-TF-IDF 점수에서 막대 차트를 만들어 각 토픽에 대해 선택된 단어들을 표시합니다. 각 토픽에 대해서 선택된 단어들을 비교할 수 있습니다.

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a3f1175b-53fe-4af9-af84-8c1f609429b1" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3f1175b-53fe-4af9-af84-8c1f609429b1")) {                    Plotly.newPlot(                        "a3f1175b-53fe-4af9-af84-8c1f609429b1",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.006364075476360552,0.007178987997684597,0.007280017511923409,0.009142755588698075,0.010506154220820617],"y":["players  ","he  ","games  ","team  ","game  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.009974575751294687,0.011926338977420358,0.012133556518235939,0.012851559457952848,0.01468492289958727],"y":["keys  ","encryption  ","chip  ","clipper  ","key  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.43134548794340793,0.4669208047021527,0.5191056437836582,0.697583857891381,0.7484399008233755],"y":["ken  ","huh  ","yep  ","cheek  ","ites  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.008493669768792716,0.01060326746161081,0.011767571122336885,0.01416228665190215,0.018824274302793882],"y":["jewish  ","arab  ","jews  ","israeli  ","israel  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.012635738082055193,0.012709567301911993,0.015766042557027894,0.021621826111016526,0.021955645849471152],"y":["vga  ","drivers  ","video  ","card  ","monitor  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.01808211458113983,0.019274207233754368,0.0229861502896249,0.027358077330910547,0.036501379524217024],"y":["disk  ","ide  ","drives  ","scsi  ","drive  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.009337409672537099,0.0096299698940889,0.011336075903236084,0.011385242198201105,0.01611920254825191],"y":["lane  ","my  ","riding  ","ride  ","bike  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.012290834702075929,0.012710334227385302,0.013816946513645867,0.014392851781654383,0.01685101015188593],"y":["condition  ","stereo  ","sound  ","audio  ","amp  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6 ...

# %% [markdown]
# # 6. 토픽 유사도 시각화

# %% [markdown]
# 각 토픽들이 서로 얼마나 유사한지 시각화할 수도 있습니다. visualize_heatmap() 메소드를 사용하여 히트맵을 시각화합니다.
# 해당 히트맵의 원하는 위치에 마우스를 갖다대면 실질적인 유사도 값을 확인할 수 있습니다.

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7e4321cc-ef7f-470c-a8d3-afea1743a7d3" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e4321cc-ef7f-470c-a8d3-afea1743a7d3")) {                    Plotly.newPlot(                        "7e4321cc-ef7f-470c-a8d3-afea1743a7d3",                        [{"coloraxis":"coloraxis","name":"0","x":["-1_to_the_of","0_game_team_games","1_key_clipper_chip","2_ites_cheek_yep","3_israel_israeli_jews","4_monitor_card_video","5_drive_scsi_drives","6_bike_ride_riding","7_amp_audio_sound","8_space_launch_station","9_car_cars_mustang","10_bike_tires_tire","11_drive_meg_ram","12_ted_post_frank","13_gun_guns_crime","14_printer_hp_deskjet","15_graphics_3d_conference","16_window_widget_application","17_db_mov_windows","18_atheists_atheism_god","19_moral_morality_objective","20_health_tobacco_cesarean","21_armenian_armenians_turkish","22_cancer_doctor_medical","23_venus_spacecraft_solar","24_men_sex_kinsey","25_dos_pom_cds","26_islam_quran_islamic","27_modem_port_serial","28_ham_radio_interference","29_pain_migraine_migraines","30_russia_tax_administration","31_serbs_muslims_stephanopo...","32_games_joystick_sega","33_koresh_batf_fbi","34_simms_simm_dram","35_homosexuality_homosexual...","36_mbytes_windows_dos","37_format_gif_files","38_windows_os2_nt","39_modem_fax_modems","40_polygon_xxxx_edge","41_fonts_font_truetype","42_candida_yeast_infection","43_sky_advertising_billboard","44_batf_warrant_raid","45_paradox_borland_windows","46_radar_detector_detectors","47_mary_her_she","48_reno_fbi_president","49_militia_amendment_arms","50_msg_food_chinese","51_ripem_key_des","52_science_methodology_scie...","53_hell_eternal_god","54_paint_wax_plastic","55_copy_protection_program","56_mhz_bus_486dx250","57_drugs_drug_cocaine","58_mouse_driver_mice","59_server_xdm_","60_miles_toyota_condition","61_were_they_azerbaijan","62_kuwait_iraq_iran","63_hst_reboost_mission","64_book_books_chemistry","65_guide_price_shipping","66_insurance_geico_car","67_christianity_life_christ...","68_greek_greece_turkish","69_battery_batteries_concrete","70_judas_books_text","71_government_libertarians_...","72_symbol_undefined_libxmul...","73_dog_dogs_bike","74_clutch_shift_shifting","75_ditto_woof_abo","76_penalty_cruel_punishment","77_oort_cloud_grbs","78_phone_dial_number","79_odometer_sensor_alarm","80_diesel_diesels_emissions","81_mhz_fpu_clock","82_kirlian_photography_leaf","83_water_dept_phd","84_motif_widgets_bindings","85_trial_boomer_cement","86_fan_cpu_heat","87_countersteering_bike_lean","88_deleted_stuff_deletion","89_ra_satan_thou","90_fire_stove_gas","91_marriage_married_marry","92_gay_homosexuals_envirole...","93_hacker_computer_hackers","94_data_ftp_image","95_graphics_ray_3d","96_jehovah_elohim_lord","97_lyme_disease_votes","98_duo_clock_date","99_exist_existence_god","100_insurance_health_private","101_cancer_medical_center","102_tape_backup_tapes","103_xv_copyright_donation","104_thinwire_adapter_mac","105_oil_drain_car","106_maxaxaxaxaxaxaxaxaxaxax...","107_1st_wolverine_comics","108_celp_dsp_speech","109_helmet_liner_foam","110_truth_absolute_bible","111_monitor_off_turn","112_shaft_wheelie_wheelies","113_dealer_saturn_car","114_ghostscript_postscript_...","115_uv_leds_blue","116_scanner_logitech_ocr","117_andi_pseudodisclaimer_s...","118_aaron_baptism_sin","119_lens_camera_nikon","120_sco_newsgroup_newsgroups","121_gc_lutindex_lut","122_pds_lc_nubus","123_software_shuttle_elements","124_pope_church_schism","125_duke_gritz_quayle","126_ks_book_author","127_eye_prk_cornea","128_internet_advertising_im...","129_scope_scopes_oscilloscope","130_jesus_prayers_god","131_abortion_women_abortions","132_zane_2ti_book","133_law_jesus_god","134_him_ups_truck","135_myers_stephan ...

# %% [markdown]
# # 7. 토픽의 수 정하기

# %% [markdown]
# 때때로 너무 많은 토픽이 생성되거나 너무 적은 토픽이 생성될 수 있습니다. 토픽의 수를 직접 정하고 싶다면 몇 가지 방법이 존재합니다.

# %% [markdown]
# 첫번째 방법은 모델 객체 생성 시에 nr_topics 값으로 원하는 토픽 수를 입력하여 원하는 토픽의 수를 설정할 수 있습니다. BerTopic은 유사한 토픽들을 찾아 하나의 토픽으로 병합합니다.

# %%
model = BERTopic(nr_topics=20)
topics, probabilities = model.fit_transform(docs)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fad3b705-0925-484e-8802-54bf3b91c9f8" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fad3b705-0925-484e-8802-54bf3b91c9f8")) {                    Plotly.newPlot(                        "fad3b705-0925-484e-8802-54bf3b91c9f8",                        [{"customdata":[[0,"the | in | to | he | game",1865],[1,"the | to | of | key | is",673],[2,"for | the | and | with | to",653],[3,"ites | cheek | yep | why | huh",526],[4,"the | israel | of | to | israeli",371],[5,"the | of | gun | to | and",367],[6,"car | the | and | it | is",357],[7,"the | to | you | bike | and",355],[8,"the | space | to | of | and",272],[9,"for | sale | and | condition | with",270],[10,"of | the | and | to | in",254],[11,"the | they | to | that | of",252],[12,"the | god | of | is | that",232],[13,"card | drivers | driver | the | video",206],[14,"the | server | to | is | on",198],[15,"bike | the | to | it | and",180],[16,"window | the | to | is | widget",175],[17,"drive | drives | disk | the | hard",171],[18,"cancer | of | and | health | the",152],[19,"printer | print | hp | the | deskjet",152]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>Words: %{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[1865,673,653,526,371,367,357,355,272,270,254,252,232,206,198,180,175,171,152,152],"sizemode":"area","sizeref":1.165625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1.3606112003326416,1.3519017696380615,12.008056640625,2.7249560356140137,2.583207845687866,1.229600191116333,-23.717941284179688,-23.306949615478516,2.6222755908966064,11.92275333404541,-9.69084358215332,2.277161121368408,2.8796498775482178,12.265397071838379,11.963247299194336,-23.499635696411133,12.107683181762695,12.386159896850586,-9.647433280944824,11.954401016235352],"xaxis":"x","y":[-4.244210720062256,-4.853768825531006,12.92815113067627,-2.8189992904663086,-3.52497935295105,-4.460585117340088,15.370214462280273,15.781192779541016,-4.2775187492370605,13.995279312133789,9.591405868530273,-3.9210050106048584,-3.170579433441162,13.11536979675293,12.412384986877441,15.588530540466309,12.471235275268555,13.710229873657227,9.548129081726074,13.629705429077148],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colo ...

# %% [markdown]
# 또 다른 방법은 모델이 자동으로 토픽의 수를 줄이도록 설정하는 것입니다. 이 옵션을 사용하려면 모델 객체 생성 시에 "nr_topics"의 값을 "auto"로 설정하면 됩니다.

# %%
model = BERTopic(nr_topics="auto")
topics, probabilities = model.fit_transform(docs)

# %%
# 각 토픽의 크기와 각 토픽에 할당된 단어들
model.get_topic_info()
# Out:
#      Topic  Count                                         Name
# 0       -1   6583                             -1_to_the_of_and
# 1        0   1841                         0_game_team_he_games
# 2        1   1074                    1_image_jpeg_software_for
# 3        2    663                2_key_encryption_clipper_chip
# 4        3    658                             3_god_that_he_of
# ..     ...    ...                                          ...
# 140    139     10                    139_skin_acne_dry_pimples
# 141    140     10                     140_bits_48bit_bit_color
# 142    141     10    141_circumcision_medical_parents_foreskin
# 143    142     10             142_blacks_african_white_culture
# 144    143     10  143_prozac_nutrition_depression_nutritional
#
# [145 rows x 3 columns]

# %% [markdown]
# 토픽의 개수를 지정하지 않았을 때는 0번 토픽부터 210번 토픽까지 총 211개의 토픽이 존재하였으나, 자동으로 토픽의 수가 줄어들도록 설정하자 토픽의 수가 0번부터 143번까지 총 144개로 줄어든 것을 확인할 수 있습니다.

# %% [markdown]
# # 8. 임의의 문서에 대한 예측

# %%
new_doc = docs[0]
print(new_doc)
# Out:
# I am sure some bashers of Pens fans are pretty confused about the lack
# of any kind of posts about the recent Pens massacre of the Devils. Actually,
# I am  bit puzzled too and a bit relieved. However, I am going to put an end
# to non-PIttsburghers' relief with a bit of praise for the Pens. Man, they
# are killing those Devils worse than I thought. Jagr just showed you why
# he is much better than his regular season stats. He is also a lot
# fo fun to watch in the playoffs. Bowman should let JAgr have a lot of
# fun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final
# regular season game.          PENS RULE!!!

# %%
topics, probs = model.transform([new_doc])

# %%
print('예측한 토픽 번호 :', topics)
# Out:
# 예측한 토픽 번호 : [0]

# %% [markdown]
# # 9. 모델 저장과 로드

# %%
model.save("my_topics_model")
BerTopic_model = BERTopic.load("my_topics_model")
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/_index.py:126: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
